# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.query('Sex == "female"')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.query('Sex == "male"')
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby('PassengerId').agg({'Sex': 'sum'}).sort_values('Sex', ascending= False)
# Out:
#                 Sex
# PassengerId
# 1              male
# 496            male
# 537            male
# 539            male
# 544            male
# ...             ...
# 258          female
# 679          female
# 678          female
# 449          female
# 521          female
#
# [891 rows x 1 columns]

# %%
df.groupby('PassengerId').agg({'Age': 'sum'}).sort_values('Age', ascending= False)
# Out:
#               Age
# PassengerId
# 631          80.0
# 852          74.0
# 494          71.0
# 97           71.0
# 117          70.5
# ...           ...
# 355           0.0
# 603           0.0
# 767           0.0
# 129           0.0
# 236           0.0
#
# [891 rows x 1 columns]

# %%
df.groupby('PassengerId').agg({'Age': 'mean'})
# Out:
#               Age
# PassengerId
# 1            22.0
# 2            38.0
# 3            26.0
# 4            35.0
# 5            35.0
# ...           ...
# 887          27.0
# 888          19.0
# 889           NaN
# 890          26.0
# 891          32.0
#
# [891 rows x 1 columns]

# %%
df.groupby('PassengerId').agg({'SibSp': 'sum'})
# Out:
#              SibSp
# PassengerId
# 1                1
# 2                1
# 3                0
# 4                1
# 5                0
# ...            ...
# 887              0
# 888              0
# 889              1
# 890              0
# 891              0
#
# [891 rows x 1 columns]

# %%
df.groupby('PassengerId').agg({'SibSp': 'sum'}).sort_values('SibSp', ascending= True)
# Out:
#              SibSp
# PassengerId
# 446              0
# 535              0
# 536              0
# 537              0
# 538              0
# ...            ...
# 181              8
# 864              8
# 202              8
# 160              8
# 793              8
#
# [891 rows x 1 columns]

# %%
df.groupby('PassengerId').agg({'SibSp': 'sum'}).sort_values('SibSp', ascending= False)
# Out:
#              SibSp
# PassengerId
# 160              8
# 181              8
# 202              8
# 793              8
# 847              8
# ...            ...
# 360              0
# 363              0
# 364              0
# 366              0
# 891              0
#
# [891 rows x 1 columns]

# %%
df.groupby('PassengerId').agg({'Fare': 'sum'}).sort_values('Fare', ascending= False)
# Out:
#                  Fare
# PassengerId
# 259          512.3292
# 738          512.3292
# 680          512.3292
# 89           263.0000
# 28           263.0000
# ...               ...
# 634            0.0000
# 414            0.0000
# 823            0.0000
# 733            0.0000
# 675            0.0000
#
# [891 rows x 1 columns]

# %%
df.groupby('PassengerId').agg({'Fare': 'sum'})
# Out:
#                 Fare
# PassengerId
# 1             7.2500
# 2            71.2833
# 3             7.9250
# 4            53.1000
# 5             8.0500
# ...              ...
# 887          13.0000
# 888          30.0000
# 889          23.4500
# 890          30.0000
# 891           7.7500
#
# [891 rows x 1 columns]

# %%
df.groupby('Survived').agg({'Fare': 'sum'})
# Out:
#                 Fare
# Survived
# 0         12142.7199
# 1         16551.2294

# %%
df.groupby('Survived').agg({'Age': 'mean'})
# Out:
#                 Age
# Survived
# 0         30.626179
# 1         28.343690

# %%
df.groupby('Embarked').agg({'SibSp': 'sum'})
# Out:
#           SibSp
# Embarked
# C            65
# Q            33
# S           368

# %%
df.groupby('Embarked').agg({'Parch': 'sum', 'SibSp': 'sum'})
# Out:
#           Parch  SibSp
# Embarked
# C            61     65
# Q            13     33
# S           266    368

# %%
df.groupby('Embarked').agg({'Fare': 'sum', 'Pclass': 'sum'})
# Out:
#                 Fare  Pclass
# Embarked
# C         10072.2962     317
# Q          1022.2543     224
# S         17439.3988    1514
